# %%
import csv
rows = []
with open('data/Node_Dos160.node') as f:
    reader = csv.reader(f, delimiter='\t')
    for row in reader:
        rows.append(row)

# %%
len(rows), len(my_data[:,1])
# Out:
# (160, 160)

# %%
rows[1]
# Out:
# ['0', '51', '32', 5, '0.49', 'mPFC']

# %%
results = [rows[0]]
for x, y in zip(rows, my_data[:,1]):
    x[3] = int(y)
    results.append(x)

# %%
results
# Out:
# [['6', '64', '3', 5, '0.55', 'vmPFC'],
#  ['6', '64', '3', 5, '0.55', 'vmPFC'],
#  ['0', '51', '32', 8, '0.49', 'mPFC'],
#  ['-25', '51', '27', 7, '0.89', 'aPFC'],
#  ['9', '51', '16', 5, '0.80', 'vmPFC'],
#  ['-6', '50', '-1', 3, '0.73', 'vmPFC'],
#  ['-11', '45', '17', 3, '0.05', 'vmPFC'],
#  ['8', '42', '-5', 5, '0.07', 'vmPFC'],
#  ['9', '39', '20', 7, '0.09', 'ACC'],
#  ['46', '39', '-15', 3, '0.80', 'vlPFC'],
#  ['23', '33', '47', 5, '0.94', 'supfrontal'],
#  ['-16', '29', '54', 5, '0.68', 'supfrontal'],
#  ['52', '-15', '-13', 3, '0.13', 'inftemporal'],
#  ['-59', '-25', '-15', 3, '0.72', 'inftemporal'],
#  ['1', '-26', '31', 8, '0.11', 'postcingulate'],
#  ['28', '-37', '-15', 5, '0.12', 'fusiform'],
#  ['-3', '-38', '45', 5, '0.64', 'precuneus'],
#  ['-8', '-41', '3', 5, '0.33', 'postcingulate'],
#  ['-61', '-41', '-2', 3, '0.65', 'inftemporal'],
#  ['-28', '-42', '-11', 8, '0.75', 'occipital'],
#  ['-5', '-43', '25', 5, '0.58', 'postcingulate'],
# ...

# %%
import csv
with open('Node_Dos160_C.node', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter='\t',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for x in results:
         spamwriter.writerow(x)

# %%
results
# Out:
# [['#aal 90'],
#  ['-38.65', '-5.68', '50.94', 3, '4.96', 'PreCG.L'],
#  ['41.37', '-8.21', '52.09', 4, '0.86', 'PreCG.R'],
#  ['-18.45', '34.81', '42.2', 10, '1.99', 'SFGdor.L'],
#  ['21.9', '31.12', '43.82', 10, '2.40', 'SFGdor.R'],
#  ['-16.56', '47.32', '-13.31', 10, '0.00', 'ORBsup.L'],
#  ['18.49', '48.1', '-14.02', 3, '0.83', 'ORBsup.R'],
#  ['-33.43', '32.73', '35.46', 3, '2.27', 'MFG.L'],
#  ['37.59', '33.06', '34.04', 3, '2.27', 'MFG.R'],
#  ['-30.65', '50.43', '-9.62', 3, '0.55', 'ORBmid.L'],
#  ['33.18', '52.59', '-10.73', 3, '0.57', 'ORBmid.R'],
#  ['-48.43', '12.73', '19.02', 3, '1.98', 'IFGoperc.L'],
#  ['50.2', '14.98', '21.41', 3, '0.03', 'IFGoperc.R'],
#  ['-45.58', '29.91', '13.99', 3, '0.53', 'IFGtriang.L'],
#  ['50.33', '30.16', '14.17', 3, '0.47', 'IFGtriang.R'],
#  ['-35.98', '30.71', '-12.11', 3, '0.17', 'ORBinf.L'],
#  ['41.22', '32.23', '-11.91', 3, '0.03', 'ORBinf.R'],
#  ['-47.16', '-8.48', '13.95', 4, '2.00', 'ROL.L'],
# ...

# %%
from numpy import genfromtxt
my_data = genfromtxt('output/Edge_Dos160_Binaryclustering11_0.csv', delimiter=',')

# %%
# Out:
# array([ 3.,  4., 10., 10., 10.,  3.,  3.,  3.,  3.,  3.,  3.,  3.,  3.,
#         3.,  3.,  3.,  4.,  4.,  3.,  4.,  0.,  0., 10., 10., 10., 10.,
#        10., 10.,  4.,  4., 10., 10.,  4.,  4., 10., 10.,  0.,  0.,  0.,
#         0.,  0.,  0.,  2.,  2.,  2.,  2.,  2.,  2.,  2.,  2.,  2.,  2.,
#         2.,  2.,  2.,  2.,  4.,  4.,  2.,  2.,  3.,  3.,  4.,  4., 10.,
#        10., 10., 10.,  4.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,
#         4.,  4.,  4.,  4.,  4.,  4., 10., 10.,  0.,  0.,  3., 10.])
